# %%
# リスト 7.5 スモールワールドネットワーク
import networkx as nx
import matplotlib.pyplot as plt

lists = []

min=5

max=25

for i in range(min, max):
   print(10*i)
   ws03 = nx.watts_strogatz_graph(10*i, 4, 0.3)
   lists.append(nx.average_shortest_path_length(ws03))

   nx.draw_circular(ws03, node_size=10, node_color='red')
   print("L =", nx.average_shortest_path_length(ws03))

print(lists)
# Out:
# 50
# L = 3.170612244897959
# 60
# L = 3.1932203389830507
# 70
# L = 3.5126293995859212
# 80
# L = 3.6227848101265825
# 90
# L = 3.810486891385768
# 100
# L = 3.822020202020202
# 110
# L = 3.8982485404503753
# 120
# L = 4.0247899159663865
# 130
# L = 4.282170542635659
# 140
# L = 4.0787255909558064
# 150
# L = 4.322237136465325
# 160
# L = 4.320911949685534
# 170
# L = 4.4434389140271495
# 180
# L = 4.429050279329609
# 190
# L = 4.546198830409357
# 200
# L = 4.542713567839196
# 210
# L = 4.50995670995671
# 220
# L = 4.7701120797011205
# 230
# L = 4.673780140497437
# 240
# L = 4.876011157601115
# [3.170612244897959, 3.1932203389830507, 3.5126293995859212, 3.6227848101265825, 3.810486891385768, 3.822020202020202, 3.8982485404503753, 4.0247899159663865, 4.282170542635659, 4.0787255909558064, 4.322237136465325, 4.320911949685534, 4.4434389140271495, 4.429050279329609, 4.546198830409357, 4.542713567839196, 4.50995670995671, 4.7701120797011205, 4.673780140497437, 4.876011157601115]

# %%
import numpy as np

list_a=[]
for x in range(min , max):
   list_a.append(np.log(10*x))

print(list_a)
# Out:
# [3.912023005428146, 4.0943445622221, 4.248495242049359, 4.382026634673881, 4.499809670330265, 4.605170185988092, 4.700480365792417, 4.787491742782046, 4.867534450455582, 4.941642422609304, 5.0106352940962555, 5.075173815233827, 5.135798437050262, 5.19295685089021, 5.247024072160486, 5.298317366548036, 5.3471075307174685, 5.393627546352362, 5.438079308923196, 5.480638923341991]

# %%
import pandas as pd
df = pd.DataFrame(
    list_a
)
df[1] =lists

df.columns = ['totalnumberofsites','meangraphdistance']

df
# Out:
#     totalnumberofsites  meangraphdistance
# 0             3.912023           3.170612
# 1             4.094345           3.193220
# 2             4.248495           3.512629
# 3             4.382027           3.622785
# 4             4.499810           3.810487
# 5             4.605170           3.822020
# 6             4.700480           3.898249
# 7             4.787492           4.024790
# 8             4.867534           4.282171
# 9             4.941642           4.078726
# 10            5.010635           4.322237
# 11            5.075174           4.320912
# 12            5.135798           4.443439
# 13            5.192957           4.429050
# 14            5.247024           4.546199
# 15            5.298317           4.542714
# 16            5.347108           4.509957
# 17            5.393628           4.770112
# 18            5.438079           4.673780
# 19            5.480639           4.876011

# %%
import numpy
import pandas
import matplotlib.pyplot as plt
df.plot()
df.plot.scatter(x='totalnumberofsites', y='meangraphdistance')

# %%
from sklearn.linear_model import LinearRegression

mod = LinearRegression(fit_intercept = True)
lm = mod.fit(df[["totalnumberofsites"]], df[["meangraphdistance"]])
print(lm)
 
print(mod.coef_)
print(mod.intercept_)

slope =  mod.coef_[0,0]
print(slope)

interception = mod.intercept_[0]

print(interception)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
# [[1.05545179]]
# [-1.01118052]
# 1.055451794083898
# -1.0111805210405205

# %%
x = np.linspace( 0, 6, 10)   
y = slope * x + interception
df.plot.scatter(x='totalnumberofsites', y='meangraphdistance',color="b")
plt.plot(x, y,color="r")
plt.legend()
# Out:
# No handles with labels found to put in legend.
